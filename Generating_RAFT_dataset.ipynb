# %% [markdown]
# # RAFT Dataset LlamaPack
#
# - Code taken and implemented from :
#   - https://colab.research.google.com/github/run-llama/llama_index/blob/main/llama-index-packs/llama-index-packs-raft-dataset/examples/raft_dataset.ipynb
#
#
# This LlamaPack implements RAFT: Adapting Language Model to Domain Specific RAG [paper](https://arxiv.org/abs/2403.10131)
#
# Retrieval Augmented FineTuning (RAFT) is a training recipe introduced in this paper that aims to improve the performance of large language models (LLMs) in open-book, in-domain question-answering tasks. Given a question and a set of retrieved documents, RAFT trains the LLM to identify and cite verbatim the most relevant sequences from the documents that help answer the question, while ignoring irrelevant or distracting information. By explicitly training the model to distinguish between relevant and irrelevant information and to provide evidence from the relevant documents, RAFT encourages the LLM to develop better reasoning and explanation abilities, ultimately improving its ability to answer questions accurately and rationally in scenarios where additional context or knowledge is available.
#
# A key component of RAFT is how the dataset is generated for fine-tuning. Each QA pair also includes an "oracle" document from which the answer to the question can be deduced as well as "distractor" documents which are irrelevant. During training this forces the model to learn which information is relevant/irrelevant and also memorize domain knowledge.
#
# In this notebook we will create `RAFT Dataset` using `RAFTDatasetPack` LlamaPack.

# %% [markdown]
# #### Installation

# %%
# !pip install llama-index
# !pip install llama-index-packs-raft-dataset
# !pip install llama-index-readers-remote-depth
# Out:
# Collecting llama-index
#   Downloading llama_index-0.10.53-py3-none-any.whl (6.8 kB)
# Collecting llama-index-agent-openai<0.3.0,>=0.1.4 (from llama-index)
#   Downloading llama_index_agent_openai-0.2.8-py3-none-any.whl (13 kB)
# Collecting llama-index-cli<0.2.0,>=0.1.2 (from llama-index)
#   Downloading llama_index_cli-0.1.12-py3-none-any.whl (26 kB)
# Collecting llama-index-core==0.10.53.post1 (from llama-index)
#   Downloading llama_index_core-0.10.53.post1-py3-none-any.whl (15.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 24.6 MB/s eta 0:00:00
# Collecting llama-index-embeddings-openai<0.2.0,>=0.1.5 (from llama-index)
#   Downloading llama_index_embeddings_openai-0.1.10-py3-none-any.whl (6.2 kB)
# Collecting llama-index-indices-managed-llama-cloud>=0.2.0 (from llama-index)
#   Downloading llama_index_indices_managed_llama_cloud-0.2.3-py3-none-any.whl (9.2 kB)
# Collecting llama-index-legacy<0.10.0,>=0.9.48 (from llama-index)
#   Downloading llama_index_legacy-0.9.48-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 39.0 MB/s eta 0:00:00
# Collecting llama-index-llms-openai<0.2.0,>=0.1.13 (from llama-index)
#   Downloading llama_index_llms_openai-0.1.25-py3-none-any.whl (11 kB)
# Collecting llama-index-multi-modal-llms-openai<0.2.0,>=0.1.3 (from llama-index)
#   Downloading llama_index_multi_modal_llms_openai-0.1.7-py3-none-any.whl (5.9 kB)
# Collecting llama-index-program-openai<0.2.0,>=0.1.3 (from llama-index)
#   Downloading llama_index_program_openai-0.1.6-py3-none-any.whl (5.2 kB)
# Collecting llama-index-question-gen-openai<0.2.0,>=0.1.2 (from llama-index)
#   Downloading llama_index_question_gen_openai-0.1.3-py3-none-any.whl (2.9 kB)
# Collecting llama-index-readers-file<0.2.0,>=0.1.4 (from llama-index)
#   Downloading llama_index_readers_file-0.1.29-py3-none-any.whl (38 kB)
# Collecting llama-index-readers-llama-parse>=0.1.2 (from llama-index)
#   Downloading llama_index_readers_llama_parse-0.1.6-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core==0.10.53.post1->llama-index) (6.0.1)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from llama-index-core==0.10.53.post1->llama-index) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.10/dist-packages (from llama-index-core==0.10.53.post1->llama-index) (3.9.5)
# Collecting dataclasses-json (from llama-index-core==0.10.53.post1->llama-index)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Collecting deprecated>=1.2.9.3 (from llama-index-core==0.10.53.post1->llama-index)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting dirtyjson<2.0.0,>=1.0.8 (from llama-index-core==0.10.53.post1->llama-index)
#   Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core==0.10.53.post1->llama-index) (2023.6.0)
# Collecting httpx (from llama-index-core==0.10.53.post1->llama-index)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 7.6 MB/s eta 0:00:00
# Collecting llama-cloud<0.0.7,>=0.0.6 (from llama-index-core==0.10.53.post1->llama-index)
#   Downloading llama_cloud-0.0.6-py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.8/130.8 kB 16.8 MB/s eta 0:00:00
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core==0.10.53.post1->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core==0.10.53.post1->llama-index) (3.3)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core==0.10.53.post1->llama-index) (3.8.1)
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core==0.10.53.post1->llama-index) (1.25.2)
# Collecting openai>=1.1.0 (from llama-index-core==0.10.53.post1->llama-index)
#   Downloading openai-1.35.10-py3-none-any.whl (328 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.3/328.3 kB 30.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from llama-index-core==0.10.53.post1->llama-index) (2.0.3)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core==0.10.53.post1->llama-index) (9.4.0)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core==0.10.53.post1->llama-index) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core==0.10.53.post1->llama-index) (8.4.2)
# Collecting tiktoken>=0.3.3 (from llama-index-core==0.10.53.post1->llama-index)
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 45.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core==0.10.53.post1->llama-index) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core==0.10.53.post1->llama-index) (4.12.2)
# Collecting typing-inspect>=0.8.0 (from llama-index-core==0.10.53.post1->llama-index)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from llama-index-core==0.10.53.post1->llama-index) (1.14.1)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (4.12.3)
# Collecting pypdf<5.0.0,>=4.0.1 (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index)
#   Downloading pypdf-4.2.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 24.8 MB/s eta 0:00:00
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index)
#   Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Collecting llama-parse>=0.4.0 (from llama-index-readers-llama-parse>=0.1.2->llama-index)
#   Downloading llama_parse-0.4.6-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.53.post1->llama-index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.53.post1->llama-index) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.53.post1->llama-index) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.53.post1->llama-index) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.53.post1->llama-index) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.53.post1->llama-index) (4.0.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (2.5)
# Requirement already satisfied: pydantic>=1.10 in /usr/local/lib/python3.10/dist-packages (from llama-cloud<0.0.7,>=0.0.6->llama-index-core==0.10.53.post1->llama-index) (2.8.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core==0.10.53.post1->llama-index) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core==0.10.53.post1->llama-index) (2024.6.2)
# Collecting httpcore==1.* (from httpx->llama-index-core==0.10.53.post1->llama-index)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core==0.10.53.post1->llama-index) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core==0.10.53.post1->llama-index) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx->llama-index-core==0.10.53.post1->llama-index)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.53.post1->llama-index) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.53.post1->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.53.post1->llama-index) (2024.5.15)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.1.0->llama-index-core==0.10.53.post1->llama-index) (1.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core==0.10.53.post1->llama-index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core==0.10.53.post1->llama-index) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core==0.10.53.post1->llama-index) (3.0.3)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.8.0->llama-index-core==0.10.53.post1->llama-index)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->llama-index-core==0.10.53.post1->llama-index)
#   Downloading marshmallow-3.21.3-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-core==0.10.53.post1->llama-index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-core==0.10.53.post1->llama-index) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-core==0.10.53.post1->llama-index) (2024.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->llama-index-core==0.10.53.post1->llama-index) (1.2.1)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core==0.10.53.post1->llama-index) (24.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10->llama-cloud<0.0.7,>=0.0.6->llama-index-core==0.10.53.post1->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10->llama-cloud<0.0.7,>=0.0.6->llama-index-core==0.10.53.post1->llama-index) (2.20.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->llama-index-core==0.10.53.post1->llama-index) (1.16.0)
# Installing collected packages: striprtf, dirtyjson, pypdf, mypy-extensions, marshmallow, h11, deprecated, typing-inspect, tiktoken, httpcore, httpx, dataclasses-json, openai, llama-cloud, llama-index-legacy, llama-index-core, llama-parse, llama-index-readers-file, llama-index-llms-openai, llama-index-indices-managed-llama-cloud, llama-index-embeddings-openai, llama-index-readers-llama-parse, llama-index-multi-modal-llms-openai, llama-index-cli, llama-index-agent-openai, llama-index-program-openai, llama-index-question-gen-openai, llama-index
# Successfully installed dataclasses-json-0.6.7 deprecated-1.2.14 dirtyjson-1.0.8 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 llama-cloud-0.0.6 llama-index-0.10.53 llama-index-agent-openai-0.2.8 llama-index-cli-0.1.12 llama-index-core-0.10.53.post1 llama-index-embeddings-openai-0.1.10 llama-index-indices-managed-llama-cloud-0.2.3 llama-index-legacy-0.9.48 llama-index-llms-openai-0.1.25 llama-index-multi-modal-llms-openai-0.1.7 llama-index-program-openai-0.1.6 llama-index-question-gen-openai-0.1.3 llama-index-readers-file-0.1.29 llama-index-readers-llama-parse-0.1.6 llama-parse-0.4.6 marshmallow-3.21.3 mypy-extensions-1.0.0 openai-1.35.10 pypdf-4.2.0 striprtf-0.0.26 tiktoken-0.7.0 typing-inspect-0.9.0
# Collecting llama-index-packs-raft-dataset
#   Downloading llama_index_packs_raft_dataset-0.1.6-py3-none-any.whl (5.8 kB)
# Collecting datasets<3.0.0,>=2.18.0 (from llama-index-packs-raft-dataset)
#   Downloading datasets-2.20.0-py3-none-any.whl (547 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-packs-raft-dataset) (0.10.53.post1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.18.0->llama-index-packs-raft-dataset) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.18.0->llama-index-packs-raft-dataset) (1.25.2)
# Collecting pyarrow>=15.0.0 (from datasets<3.0.0,>=2.18.0->llama-index-packs-raft-dataset)
#   Downloading pyarrow-16.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (40.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 19.7 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.18.0->llama-index-packs-raft-dataset) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets<3.0.0,>=2.18.0->llama-index-packs-raft-dataset)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 16.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.18.0->llama-index-packs-raft-dataset) (2.0.3)
# Collecting requests>=2.32.2 (from datasets<3.0.0,>=2.18.0->llama-index-packs-raft-dataset)
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.18.0->llama-index-packs-raft-dataset) (4.66.4)
# Collecting xxhash (from datasets<3.0.0,>=2.18.0->llama-index-packs-raft-dataset)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 22.5 MB/s eta 0:00:00
# Collecting multiprocess (from datasets<3.0.0,>=2.18.0->llama-index-packs-raft-dataset)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.5.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.18.0->llama-index-packs-raft-dataset) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.18.0->llama-index-packs-raft-dataset) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.18.0->llama-index-packs-raft-dataset) (0.23.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.18.0->llama-index-packs-raft-dataset) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets<3.0.0,>=2.18.0->llama-index-packs-raft-dataset) (6.0.1)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (2.0.31)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (1.0.8)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (0.27.0)
# Requirement already satisfied: llama-cloud<0.0.7,>=0.0.6 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (0.0.6)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (3.3)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (3.8.1)
# Requirement already satisfied: openai>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (1.35.10)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (9.4.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (8.4.2)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (0.7.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (1.14.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.18.0->llama-index-packs-raft-dataset) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.18.0->llama-index-packs-raft-dataset) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.18.0->llama-index-packs-raft-dataset) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.18.0->llama-index-packs-raft-dataset) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.18.0->llama-index-packs-raft-dataset) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<3.0.0,>=2.18.0->llama-index-packs-raft-dataset) (4.0.3)
# Requirement already satisfied: pydantic>=1.10 in /usr/local/lib/python3.10/dist-packages (from llama-cloud<0.0.7,>=0.0.6->llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (2.8.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (1.0.5)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (0.14.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (2024.5.15)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (1.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets<3.0.0,>=2.18.0->llama-index-packs-raft-dataset) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets<3.0.0,>=2.18.0->llama-index-packs-raft-dataset) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (3.21.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets<3.0.0,>=2.18.0->llama-index-packs-raft-dataset) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets<3.0.0,>=2.18.0->llama-index-packs-raft-dataset) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets<3.0.0,>=2.18.0->llama-index-packs-raft-dataset) (2024.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (1.2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10->llama-cloud<0.0.7,>=0.0.6->llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10->llama-cloud<0.0.7,>=0.0.6->llama-index-core<0.11.0,>=0.10.0->llama-index-packs-raft-dataset) (2.20.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets<3.0.0,>=2.18.0->llama-index-packs-raft-dataset) (1.16.0)
# Installing collected packages: xxhash, requests, pyarrow, dill, multiprocess, datasets, llama-index-packs-raft-dataset
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 16.1.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 16.1.0 which is incompatible.
# Successfully installed datasets-2.20.0 dill-0.3.8 llama-index-packs-raft-dataset-0.1.6 multiprocess-0.70.16 pyarrow-16.1.0 requests-2.32.3 xxhash-3.4.1
# Collecting llama-index-readers-remote-depth
#   Downloading llama_index_readers_remote_depth-0.1.4-py3-none-any.whl (3.6 kB)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.11.post1 in /usr/local/lib/python3.10/dist-packages (from llama-index-readers-remote-depth) (0.10.53.post1)
# Collecting llama-index-readers-remote<0.2.0,>=0.1.1 (from llama-index-readers-remote-depth)
#   Downloading llama_index_readers_remote-0.1.4-py3-none-any.whl (3.5 kB)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (6.0.1)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (3.9.5)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (2023.6.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (0.27.0)
# Requirement already satisfied: llama-cloud<0.0.7,>=0.0.6 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (0.0.6)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (3.3)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (3.8.1)
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (1.25.2)
# Requirement already satisfied: openai>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (1.35.10)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (2.0.3)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (9.4.0)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (8.4.2)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (1.14.1)
# Collecting llama-index-readers-youtube-transcript<0.2.0,>=0.1.4 (from llama-index-readers-remote<0.2.0,>=0.1.1->llama-index-readers-remote-depth)
#   Downloading llama_index_readers_youtube_transcript-0.1.4-py3-none-any.whl (3.7 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (4.0.3)
# Requirement already satisfied: pydantic>=1.10 in /usr/local/lib/python3.10/dist-packages (from llama-cloud<0.0.7,>=0.0.6->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (2.8.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (1.0.5)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (0.14.0)
# Collecting youtube-transcript-api>=0.5.0 (from llama-index-readers-youtube-transcript<0.2.0,>=0.1.4->llama-index-readers-remote<0.2.0,>=0.1.1->llama-index-readers-remote-depth)
#   Downloading youtube_transcript_api-0.6.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (2024.5.15)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (1.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (3.21.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (2024.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (1.2.1)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (24.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10->llama-cloud<0.0.7,>=0.0.6->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10->llama-cloud<0.0.7,>=0.0.6->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (2.20.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.11.post1->llama-index-readers-remote-depth) (1.16.0)
# Installing collected packages: youtube-transcript-api, llama-index-readers-youtube-transcript, llama-index-readers-remote, llama-index-readers-remote-depth
# Successfully installed llama-index-readers-remote-0.1.4 llama-index-readers-remote-depth-0.1.4 llama-index-readers-youtube-transcript-0.1.4 youtube-transcript-api-0.6.2

# %%
import os

os.environ["OPENAI_API_KEY"] = # OpenAI API key

# %% [markdown]
# #### Download Data

# %%
from google.colab import drive
drive.mount('/content/drive')
smth = '/content/drive/MyDrive/ColabNotebooks/Parsing/hedera_coinmarketcap.txt'
# Out:
# Mounted at /content/drive
# '\nAttempting to load url sites\n\nfrom llama_index.readers.remote_depth import RemoteDepthReader\n\nloader = RemoteDepthReader() # if you want to extract the links in the page, and the links in the links in the page, you need to specify depth=2\ndocuments = loader.load_data(\n    url="https://hedera.com/journey"\n)\n'

# %%
from llama_index.packs.raft_dataset import RAFTDatasetPack

# %%
raft_dataset = RAFTDatasetPack(smth)

# %%
# Beware of the costs invloved. This will use GPT-4 for dataset creation.
# It will also take long time based on the file size.
dataset = raft_dataset.run()
# Out:
# INFO:llama_index.packs.raft_dataset.base:Number of chunks created: 6
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 0
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 1
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 2
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 3
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 4
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 5

# %% [markdown]
# The above dataset is HuggingFace Dataset format. You can then save it into `.arrow` or `.jsonl` format and use it for further finetuning.

# %%
output_path = "/content/drive/MyDrive/ColabNotebooks/RAFT-implementation/hedera_CM"
# Save as .arrow format
dataset.save_to_disk(output_path)

# Save as .jsonl format
dataset.to_json(output_path + ".jsonl")
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/30 [00:00<?, ? examples/s]
# Creating json from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# 381018

# %%
hedera_whitepaper = '/content/drive/MyDrive/ColabNotebooks/Parsing/hedera_whitepaper_parts.txt'

# %%
raft_dataset = RAFTDatasetPack(hedera_whitepaper)

# %%
output_path = "/content/drive/MyDrive/ColabNotebooks/RAFT-implementation/hedera_whitepaper"
# Save as .arrow format
dataset.save_to_disk(output_path)

# Save as .jsonl format
dataset.to_json(output_path + ".jsonl")
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/45 [00:00<?, ? examples/s]
# Creating json from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# 793573

# %% [markdown]
# # Algorand

# %%
algorand = '/content/drive/MyDrive/ColabNotebooks/Parsing/Algorand_coinmarketcap.txt'
raft_dataset = RAFTDatasetPack(algorand)
dataset = raft_dataset.run()

output_path = "/content/drive/MyDrive/ColabNotebooks/RAFT-implementation/algorand"
# Save as .arrow format
dataset.save_to_disk(output_path)

# Save as .jsonl format
dataset.to_json(output_path + ".jsonl")
# Out:
# INFO:llama_index.packs.raft_dataset.base:Number of chunks created: 5
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 0
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 1
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 2
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 3
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 4
# Saving the dataset (0/1 shards):   0%|          | 0/25 [00:00<?, ? examples/s]
# Creating json from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# 328802

# %% [markdown]
# #Cardano

# %%
cardano = '/content/drive/MyDrive/ColabNotebooks/Parsing/Cardano_coinmarketcap.txt'
raft_dataset = RAFTDatasetPack(cardano)
dataset = raft_dataset.run()

output_path = "/content/drive/MyDrive/ColabNotebooks/RAFT-implementation/cardano"
# Save as .arrow format
dataset.save_to_disk(output_path)

# Save as .jsonl format
dataset.to_json(output_path + ".jsonl")
# Out:
# INFO:llama_index.packs.raft_dataset.base:Number of chunks created: 8
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 0
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 1
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 2
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 3
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 4
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 5
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 6
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 7
# Saving the dataset (0/1 shards):   0%|          | 0/40 [00:00<?, ? examples/s]
# Creating json from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# 657186

# %% [markdown]
# # Solana

# %%
solana = '/content/drive/MyDrive/ColabNotebooks/Parsing/Solana.txt'
raft_dataset = RAFTDatasetPack(solana)
dataset = raft_dataset.run()

output_path = "/content/drive/MyDrive/ColabNotebooks/RAFT-implementation/solana"
# Save as .arrow format
dataset.save_to_disk(output_path)

# Save as .jsonl format
dataset.to_json(output_path + ".jsonl")
# Out:
# INFO:llama_index.packs.raft_dataset.base:Number of chunks created: 8
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 0
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 1
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 2
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 3
# /usr/local/lib/python3.10/dist-packages/llama_index/packs/raft_dataset/base.py:118: UserWarning: Fewer questions generated (1) than requested (5).
#   warnings.warn(
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 4
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 5
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 6
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 7
# Saving the dataset (0/1 shards):   0%|          | 0/36 [00:00<?, ? examples/s]
# Creating json from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# 561721

# %% [markdown]
# # ChainLink

# %%
link = '/content/drive/MyDrive/ColabNotebooks/Parsing/Chainlink.txt'
raft_dataset = RAFTDatasetPack(link)
dataset = raft_dataset.run()

output_path = "/content/drive/MyDrive/ColabNotebooks/RAFT-implementation/Chainlink"
# Save as .arrow format
dataset.save_to_disk(output_path)

# Save as .jsonl format
dataset.to_json(output_path + ".jsonl")
# Out:
# INFO:llama_index.packs.raft_dataset.base:Number of chunks created: 6
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 0
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 1
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 2
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 3
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 4
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 5
# Saving the dataset (0/1 shards):   0%|          | 0/30 [00:00<?, ? examples/s]
# Creating json from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# 524816

# %% [markdown]
# # Whitepaper consensus sections

# %%
link = '/content/drive/MyDrive/ColabNotebooks/Parsing/cardano_whitepaper.txt'
raft_dataset = RAFTDatasetPack(link)
dataset = raft_dataset.run()

output_path = "/content/drive/MyDrive/ColabNotebooks/RAFT-implementation/cardano_ww"
# Save as .arrow format
dataset.save_to_disk(output_path)

# Save as .jsonl format
dataset.to_json(output_path + ".jsonl")
# Out:
# INFO:llama_index.packs.raft_dataset.base:Number of chunks created: 2
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 0
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 1
# Saving the dataset (0/1 shards):   0%|          | 0/10 [00:00<?, ? examples/s]
# Creating json from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# 98735

# %%
link1 = '/content/drive/MyDrive/ColabNotebooks/Parsing/solana_whitepaper.txt'
raft_dataset1 = RAFTDatasetPack(link1)
dataset1 = raft_dataset1.run()

output_path1 = "/content/drive/MyDrive/ColabNotebooks/RAFT-implementation/solana_ww"
# Save as .arrow format
dataset1.save_to_disk(output_path1)

# Save as .jsonl format
dataset1.to_json(output_path1 + ".jsonl")
# Out:
# INFO:llama_index.packs.raft_dataset.base:Number of chunks created: 2
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 0
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 1
# Saving the dataset (0/1 shards):   0%|          | 0/10 [00:00<?, ? examples/s]
# Creating json from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# 84899

# %%
link2 = '/content/drive/MyDrive/ColabNotebooks/Parsing/chainlink_whitepaper.txt'
raft_dataset2 = RAFTDatasetPack(link2)
dataset2 = raft_dataset2.run()

output_path = "/content/drive/MyDrive/ColabNotebooks/RAFT-implementation/chainlink_ww"
# Save as .arrow format
dataset2.save_to_disk(output_path)

# Save as .jsonl format
dataset2.to_json(output_path + ".jsonl")
# Out:
# INFO:llama_index.packs.raft_dataset.base:Number of chunks created: 3
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 0
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 1
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 2
# Saving the dataset (0/1 shards):   0%|          | 0/15 [00:00<?, ? examples/s]
# Creating json from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# 145677

# %%
link3 = '/content/drive/MyDrive/ColabNotebooks/Parsing/Hedera_whitepaper_2.txt'
raft_dataset3 = RAFTDatasetPack(link3)
dataset3 = raft_dataset3.run()

output_path = "/content/drive/MyDrive/ColabNotebooks/RAFT-implementation/hedera_ww_2"
# Save as .arrow format
dataset3.save_to_disk(output_path)

# Save as .jsonl format
dataset3.to_json(output_path + ".jsonl")
# Out:
# INFO:llama_index.packs.raft_dataset.base:Number of chunks created: 5
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 0
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 1
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 2
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 3
# INFO:llama_index.packs.raft_dataset.base:Processing chunk: 4
# Saving the dataset (0/1 shards):   0%|          | 0/25 [00:00<?, ? examples/s]
# Creating json from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# 389184

# %% [markdown]
# #### You can refer to the original implementation [here](https://github.com/ShishirPatil/gorilla/tree/main/raft)
